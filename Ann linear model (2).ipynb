# %%
import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import keras.models as km
from keras.models import Sequential
from keras import activations, initializers, regularizers, constraints
from keras.layers import Dense, Activation

# %%
dataset=pd.read_csv(r"C:\Users\mr.shoaib\Downloads\smart_campus_dataset_100k.csv")

# %%
dataset
# Out:
#        hour_index  day_index  week_index  space_id  capacity  occupancy_count  \
# 0               6          3          16       165        97               84
# 1              19          4           5       137       113               94
# 2              14          7           4        21       137              133
# 3              10          6          27         5        83               34
# 4               7          7           4       178        83               54
# ...           ...        ...         ...       ...       ...              ...
# 99995           7          4          23       153        32                6
# 99996           4          6          34        65        38               36
# 99997          10          4          14       182       184              159
# 99998           1          4          41       186       131               48
# 99999          18          7          18        75        51                8
#
#        utilization_ratio  idle_minutes  power_kwh  hvac_state  ...  \
# 0                   0.87            13      42.37           1  ...
# 1                   0.83            12      33.97           0  ...
# 2                   0.97            40      49.41           0  ...
# 3                   0.41             3      48.29           0  ...
# 4                   0.65            50      24.89           0  ...
# ...                  ...           ...        ...         ...  ...
# 99995               0.19            55      43.28           1  ...
# 99996               0.95            23      38.44           1  ...
# 99997               0.86            30       9.48           0  ...
# 99998               0.37             9      47.29           1  ...
# 99999               0.16            19      20.24           0  ...
#
#        voltage_variation  device_temperature  zone_id  connected_devices  \
# 0                   9.39                63.1       17                390
# 1                   2.14                54.2       14                283
# 2                   6.81                56.6       13                135
# 3                   0.57                53.5       11                 35
# 4                   0.55                25.1        6                436
# ...                  ...                 ...      ...                ...
# 99995               6.69                28.3       13                444
# 99996               8.45                44.9       19                326
# 99997               0.02                38.2       18                386
# 99998               3.90                88.7       18                110
# 99999               6.72                75.9       13                242
#
#        bandwidth_usage  packet_loss_rate  corridor_id  entry_count  \
# 0               211.72              4.90           25          252
# 1               333.72              0.88            4          122
# 2               823.41              4.45           24          330
# 3               300.11              8.93            7           24
# 4                 0.54              8.71            4           55
# ...                ...               ...          ...          ...
# 99995           405.25              1.89            6          181
# 99996           534.05              0.44            5          232
# 99997           867.65              7.06           27           97
# 99998           157.81              5.71           27          259
# 99999           785.22              4.98           18          103
#
#        exit_count  density_index
# 0             284           4.02
# 1              32           4.82
# 2              35           2.48
# 3             453           1.53
# 4             133           2.94
# ...           ...            ...
# 99995         264           3.32
# 99996         319           2.57
# 99997         105           3.32
# 99998         282           1.71
# 99999         321           3.32
#
# [100000 rows x 26 columns]

# %%
dataset["density_index"].value_counts()
# Out:
# density_index
# 3.90    243
# 4.89    239
# 0.15    239
# 1.97    238
# 2.00    235
#        ...
# 4.56    165
# 0.37    161
# 3.96    154
# 5.00    113
# 0.00    109
# Name: count, Length: 501, dtype: int64

# %%
X = dataset.drop(columns=['density_index'])
y = dataset['density_index']

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.3, random_state =123)

# %%
train_X.shape
# Out:
# (70000, 25)

# %%
model = Sequential()
model.add(Dense(units = 64, kernel_initializer = 'uniform', activation = 'relu', input_dim = 25))
model.add(Dense(units = 32, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'linear'))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │           1,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,777 (14.75 KB)
#  Trainable params: 3,777 (14.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
print(train_X.shape)
print(train_y.shape)
# Out:
# (70000, 25)
# (70000,)

# %%
model.fit(train_X, train_y, epochs=50, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 2.2148 - val_loss: 2.1107
# Epoch 2/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 2.1570 - val_loss: 2.1035
# Epoch 3/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 2.1379 - val_loss: 2.0911
# Epoch 4/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 2.1297 - val_loss: 2.0827
# Epoch 5/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.1207 - val_loss: 2.1256
# Epoch 6/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 2.1150 - val_loss: 2.0839
# Epoch 7/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 2.1082 - val_loss: 2.0759
# Epoch 8/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 2.1043 - val_loss: 2.0720
# Epoch 9/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 2.1013 - val_loss: 2.0770
# Epoch 10/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 2.0975 - val_loss: 2.0850
# Epoch 11/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 2.0967 - val_loss: 2.0605
# Epoch 12/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 2.0947 - val_loss: 2.0656
# Epoch 13/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 2.0909 - val_loss: 2.0610
# Epoch 14/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 2.0900 - val_loss: 2.0611
# Epoch 15/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 2.0884 - val_loss: 2.0585
# Epoch 16/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 2.0868 - val_loss: 2.0613
# Epoch 17/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - loss: 2.0844 - val_loss: 2.0610
# Epoch 18/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 2.0848 - val_loss: 2.0627
# Epoch 19/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 2.0837 - val_loss: 2.0593
# Epoch 20/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.0824 - val_loss: 2.0589
# Epoch 21/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 2.0828 - val_loss: 2.0595
# Epoch 22/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 2.0821 - val_loss: 2.0596
# Epoch 23/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 2.0820 - val_loss: 2.0558
# Epoch 24/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 2.0808 - val_loss: 2.0576
# Epoch 25/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 2.0808 - val_loss: 2.0581
# Epoch 26/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 2.0804 - val_loss: 2.0588
# Epoch 27/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 2.0804 - val_loss: 2.0684
# Epoch 28/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 2.0803 - val_loss: 2.0564
# Epoch 29/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 2.0799 - val_loss: 2.0568
# Epoch 30/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 2.0798 - val_loss: 2.0563
# Epoch 31/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2.0800 - val_loss: 2.0567
# Epoch 32/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 2.0795 - val_loss: 2.0570
# Epoch 33/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 2.0794 - val_loss: 2.0571
# Epoch 34/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 2.0790 - val_loss: 2.0568
# Epoch 35/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 2.0792 - val_loss: 2.0588
# Epoch 36/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 2.0784 - val_loss: 2.0563
# Epoch 37/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 2.0790 - val_loss: 2.0595
# Epoch 38/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 2.0788 - val_loss: 2.0599
# Epoch 39/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 2.0789 - val_loss: 2.0583
# Epoch 40/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 2.0788 - val_loss: 2.0592
# Epoch 41/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 2.0788 - val_loss: 2.0647
# Epoch 42/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.0781 - val_loss: 2.0697
# Epoch 43/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 2.0786 - val_loss: 2.0610
# Epoch 44/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 2.0782 - val_loss: 2.0629
# Epoch 45/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 2.0777 - val_loss: 2.0642
# Epoch 46/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 2.0781 - val_loss: 2.0613
# Epoch 47/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 2.0782 - val_loss: 2.0574
# Epoch 48/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 2.0777 - val_loss: 2.0579
# Epoch 49/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 2.0773 - val_loss: 2.0597
# Epoch 50/50
# 1969/1969 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 2.0772 - val_loss: 2.0585

# %%
predictions = model.predict(test_X)
predictions
# Out:
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# array([[2.4815013],
#        [2.4815013],
#        [2.4815013],
#        ...,
#        [2.4815013],
#        [2.4815013],
#        [2.4815013]], shape=(30000, 1), dtype=float32)

# %%
# Model ko save karein
# Trained model ko keras file format me save karein
model.save("smart_campus_model.keras")

# %%
# %%writefile app.py
import numpy as np
import pandas as pd
import streamlit as st
import tensorflow as tf

st.set_page_config(page_title="Smart Campus Density Predictor", layout="wide")
st.title("Smart Campus Density Index Prediction")

# Model load handler
@st.cache_resource
def load_keras_model():
    return tf.keras.models.load_model('smart_campus_model.keras')

try:
    model = load_keras_model()
    st.success("Model Successfully Loaded!")
except Exception as e:
    st.error(f"Model Loading Error: {e}")
    st.stop()

# Dataset ke 25 Features
feature_cols = [
    'hour_index', 'day_index', 'week_index', 'space_id', 'capacity',
    'occupancy_count', 'utilization_ratio', 'idle_minutes', 'power_kwh',
    'hvac_state', 'voltage_variation', 'device_temperature', 'zone_id',
    'connected_devices', 'bandwidth_usage', 'packet_loss_rate',
    'corridor_id', 'entry_count', 'exit_count', 'feature_20',
    'feature_21', 'feature_22', 'feature_23', 'feature_24', 'feature_25'
]

st.subheader("Enter Values for Prediction")
input_data = {}
cols = st.columns(3)

for i, col_name in enumerate(feature_cols):
    with cols[i % 3]:
        input_data[col_name] = st.number_input(f"{col_name}", value=0.0)

if st.button("Predict Density Index"):
    input_df = pd.DataFrame([input_data])
    prediction = model.predict(input_df)[0][0]
    st.success(f"Predicted Density Index: **{prediction:.2f}**")
# Out:
# Writing app.py

# %%
# !py -m streamlit run app.py
